# %% [markdown]
# <a href="https://colab.research.google.com/github/FranVaquer92/IA3_UV_Vaquer/blob/main/Batmobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![batmobile.png](data:image/png;base64,...)

# %% [markdown]
# # Consideraciones:
#
# - Se trata de un ejercicio opcional a realizar en grupos de tres
# - El entregable de este ejercicio debe ser un link a vuestro cuaderno de colaboratory alojado en Github
# - La evaluación del ejercicio será una ejecución del cuaderno
# - Todos los métodos descritos deben imprimir un resultado en pantalla
# - Aquellos que completen el sistema discreto recibirán un punto extra en este módulo
# - **Se dispone de un total de dos semanas para terminar el ejercicio (aunque lo empezamos ahora)**
#
# Este ejercicio se propone dada la importancia de la programación orientada a objetos en el lenguaje Python. Gran parte de las librerías utilizadas en ML y DL requieren de un conocimiento básico de este paradigma para poder sacarles provecho y modelar de forma apropiada. Debido a este se propone este ejercicio para motivar a los alumnos a familiarizarse con esta tecnología.

# %% [markdown]
# # Exercise 1
# Hi Guys Cristopher Nolan is here. Don't talk about this, but I am making a new Batman movie and I need your help to design the new Batmobile. For this ocassion I would like you to design it as several Python Classes.
#
# - Design the main Batmobile class with the following attributes: Pilot (It could be Batman or Robin), number of batrockets loaded, number of pem (this are electromagnetic pulses to counter the Joker weapons) uses left, liters of gas left in the batmobile
#
# - Add the following methods to the Batmobile class: A method to accelerate the batmobile and drive for some distance, a method to activate the turbo and drive for some distance faster than the normal method, a method to launch a rocket to a Joker colleague, a method to launch a pem use.
#
# - Create the following classes to interact with the Batmobile: Joker, Joker Villain, Rocket, PEM Pulse.
#
# - The Joker and Jokker Villain class should have a parameter called KO which will turn to True when they receive a Rocket. They also have a parameter called Weapon which should turn to false if they receive a PEM Pulse.
#
# - The Rocket and PEM Pulse are the ammunition of the Batmobile, the car can only use the weapons if it has ammunition in the arsenal.
#
# - Finally draw a diagram of the classes using diagram.io showing how they interact.

# %% [markdown]
# Se propone la siguiente distribución de la carga de trabajo:
# - Un estudiante podría diseñar la clase del batmóvil. Mientras sus dos compañeros podrían desarrollar las clases relacionadas con el armamento del mismo y los distintos villanos descritos.
# - Una vez desarrolladas las piezas de código por separado se procedería a la integración en equipo de todo el sistema.
# - Uno de los estudiantes (aquel con menor carga en programación) desarrollaría el diagrama de la pieza de software.

# %% [markdown]
# # SOLUTION

# %% [markdown]
# We are the team ..... represented by:
#
# - Francisco Vaquer
# - Marina Souto
# - Juan Francisco Vallalta

# %% [markdown]
# ![Guion_Nolan_Dark_Knight.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **To my friend Bruce**

# %% [markdown]
# Hi, I am your technology partner and friend Lucius Fox. I have listened to your request and I have made the job. Pay attention please, I will explain how it works:
#
# First we create the batmobile class. This class have the following attributes:
#   - Pilot: There ara two posibilities to drive the batmobile, the driver must be Batman or Robin. if the Pilot is different, the code return an error.
#   - n_batrockets: This attribute must be of class rocket (we explain this class later). If the class is different the code return an error.
#   - n_pem: This attribute must be of class pem (we explain this class later). If the class is different the code return an error.
#   - gas: This attribute is type int and reflex the percent of gas remains in the batmobile. The level of gas must be 0 to 100, otherwise the code return an error.
#
# Later we have created the following methods:
# 1. describe_status(): This method is used to describe condition of batmobile.
# 2. accelerate(): This method is used to drive the car and have the attribute "distance" that it's meaning is the km that the car want to moved. The car only moved if have enough gas. With this movement the consumition is (0,5*distance) % of gas. If the batmobile don't have enough gas, the method return an error.
# 3. turbo(): This method is similar to accelerate() but have one difference, as the car travels faster, it uses more gas. If the batmobile don't have enough gas, the method return an error.
# 4. launch_batrocket(): This method is used to launch botrocket to an "enemy" that it's the attribute. It can only be used if it has ammonition. Otherwise, the code will return an error. If you launch a rocket to the enemy, the enemy will dead. To kill the enemy, this method calls a joker or joker_villain class attribute.
# 5. launch_pem(): This method is similar than the last one. The use of this is to unarmed the "enemy" that it's the attribute. It can only be used if it has ammonition. Otherwise, the code will return an error. From this method we call to joker class attribute.
#
#
# Secondly we create the jaker and joker_villain classes. This class have the following attributes:
#  - KO: This attribute is False if the joker is alive and True if the joker is dead.
#  - weapon: This attribute is True if the wepon is avaliable and is False if the enemy is unarmed.
#
# The class joker and joker_villain have this methods:
# 1. joker_KO(): If this method is called, the joker will dead.
# 2. joker_unweapon(): This method is used to unarmed the enemy.
# 3. describe_status(): This method is used to describe the condition of the enemy.
#
# Finally, we create two similar classes. That classes are rocket and pem. This class have the  following attributes:
# - ammunition: Number of pem or rockets that the batmobile can use.
#
# The methods of the class pem and rocket are:
# 1. recharge_ammunition(): This method is used to add more rockets or pem. It has the attribute "recharge" to indicate the number of ammunition add.
# 2. consum_ammunition(): This method is used to subtract ammunition from rocket or pem.
# 3. check(): This method is used to return the ammunition remains.
#
# Then, this is the code:

# %%
class batmobile:
  def __init__(self, pilot, n_batrockets, n_pem, gas):
    if pilot == 'Batman' or pilot == 'Robin':
      self.pilot = pilot
    else:
      raise Exception("You are not worthy to drive the batmobile")
    if isinstance(n_batrockets, rocket):
      self.n_batrockets = n_batrockets
    else:
      raise Exception("There aren't rockets!")
    if isinstance(n_pem, pem):
      self.n_pem = n_pem
    else:
      raise Exception("There aren't pem!")
    if gas <= 100 and gas >= 0:
      self.gas = gas
    else:
      raise Exception('The level of gas must be 0 to 100')
  def describe_status(self):
    print(f"The batmobile is drived by {self.pilot}, has {self.n_batrockets.check()} batrockets and {self.n_pem.check()} pem. {self.gas} % of gas reamins")
  def accelerate(self, distance):
    if (0.5*distance) <= self.gas:
      self.gas = self.gas-(0.5*distance)
      print(f"{self.pilot} drive for {distance} km and {self.gas} % of gas remains")
    else:
      raise Exception("There are not gas! You can't accelerate")
  def turbo(self, distance):
    if (1*distance) <= self.gas:
      self.gas = self.gas-(1*distance)
      print(f"{self.pilot} drive fastly for {distance} km and {self.gas} % of gas remains")
    else:
      raise Exception("There are not gas! You can't use the turbo")
  def launch_batrocket(self, enemy):
    if self.n_batrockets.check() > 0:
      print(f"The batrocket is launched")
      self.n_batrockets.consum_ammunition()
      enemy.joker_ko()
    else:
      raise Exception("There aren't batrockets, you must recharge")
  def launch_pem(self, enemy):
    if self.n_pem.check() > 0:
      print(f"The pem is launched")
      self.n_pem.consum_ammunition()
      enemy.joker_unweapon()
    else:
      raise Exception("There aren't pem, you must recharge")

class joker:
  def __init__(self,KO=False, weapon=True):
    self.KO = KO
    self.weapon = weapon
  def joker_ko(self):
    self.KO = True
    print(f"The joker is dead")
  def joker_unweapon(self):
    self.weapon = False
    print(f"The joker is unarmed")
  def describe_status(self):
    if self.KO == True:
      print(f"The joker is dead")
    elif self.weapon == True:
      print(f"Oh my god! The joker is alive and armed!")
    else:
      print(f"The joker is alive but he is unarmed")
      
  
class joker_villain:
  def __init__(self,KO=False, weapon=True):
    self.KO = KO
    self.weapon = weapon
  def joker_ko(self):
    self.KO = True
    print(f"The joker villain is dead")
  def joker_unweapon(self):
    self.weapon = False
    print(f"The joker villain is unarmed")
  def describe_status(self):
    if self.KO == True:
      print(f"The joker is dead")
    elif self.weapon == True:
      print(f"Oh my god! The joker villain is alive and armed!")
    else:
      print(f"The joker villain is alive but he is unarmed")

class rocket:
  def __init__(self, ammunition):
    self.ammunition = ammunition
  def recharge_ammunition(self, recharge):
    self.ammunition = self.ammunition + recharge
    print(f"Good job! The rocket arsenal is recharged to {self.ammunition}")
  def consum_ammunition(self):
    self.ammunition = self.ammunition - 1
    print(f"There are {self.ammunition} batrockets")
  def check(self):
    return self.ammunition

class pem:
  def __init__(self, ammunition):
    self.ammunition = ammunition
  def recharge_ammunition(self, recharge):
    self.ammunition = self.ammunition + recharge
    print(f"Good job! The pem arsenal is recharged to {self.ammunition}")
  def consum_ammunition(self):
    self.ammunition = self.ammunition - 1
    print(f"There are {self.ammunition} pem")
  def check(self):
    return self.ammunition

# %% [markdown]
# I understand that you want to see it in operation. Let's see an example:
#
# First we initialize the classes and pass th attributes to them.

# %%
batrocket = rocket(5)
PEM = pem(3)
batprueba = batmobile('Batman', batrocket, PEM, 100)
TheJoker = joker()
JokerVillain = joker_villain()

# %% [markdown]
# Ok, we are going to try to accelerate for 20 km.

# %%
batprueba.accelerate(20)
# Out:
# Batman drive for 20 km and 90.0 % of gas remains

# %% [markdown]
# Yes, at this speed the joker would run away. Try the turbo:

# %%
batprueba.turbo(50)
# Out:
# Batman drive fastly for 50 km and 40.0 % of gas remains

# %% [markdown]
# The joker is here..

# %%
TheJoker.describe_status()
# Out:
# Oh my god! The joker is alive and armed!

# %% [markdown]
# Let's go Bruce, you must launch a batrocket to kill the enemy.

# %%
batprueba.launch_batrocket(TheJoker)
# Out:
# The batrocket is launched
# There are 4 batrockets
# The joker is dead

# %% [markdown]
# I think that the joker is dead...

# %%
TheJoker.describe_status()
# Out:
# The joker is dead

# %% [markdown]
# Another enemy! Camon Bruce, unarm the Joker Villain!

# %%
batprueba.launch_pem(JokerVillain)
# Out:
# The pem is launched
# There are 2 pem
# The joker villain is unarmed

# %%
JokerVillain.describe_status()
# Out:
# The joker villain is alive but he is unarmed

# %% [markdown]
# Good job! Let's see the status of the batmobile.

# %%
batprueba.describe_status()
# Out:
# The batmobile is drived by Batman, has 4 batrockets and 2 pem. 40.0 % of gas reamins

# %% [markdown]
# Recharge the ammunition in case Bane appears.

# %%
batrocket.recharge_ammunition(6)
PEM.recharge_ammunition(10)
# Out:
# Good job! The rocket arsenal is recharged to 10
# Good job! The pem arsenal is recharged to 12

# %%
batprueba.describe_status()
# Out:
# The batmobile is drived by Batman, has 10 batrockets and 12 pem. 40.0 % of gas reamins

# %% [markdown]
# That's all Bruce! Finnaly, show how the classes interact:

# %% [markdown]
# ![BATMOBILE (3).jpg](data:image/jpeg;base64,...)
